# %% [markdown]
# #About this notebook
#
# Here, we run the Granger Causality test on 100 NSE stocks from 10 sectors, from the timeline 23/5/20 (beginning of lockdown) to today. To change this to post-covid19 analysis, we simply change the timelines to something well before the pandemic, to analyze causality under normal conditions as compared to now.

# %%
#IMPORTING THE LIBRARIES WE WILL BE USING
import numpy as np
import pandas as pd
import pandas_datareader as pdr
import statsmodels.tsa.stattools as ts
import matplotlib.pyplot as plt
from datetime import date
import requests
from urllib.error import HTTPError
import itertools
from statistics import stdev 
from google.colab import drive
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
today = date.today()

# %%
#@title Default title text
stox_1=[]
stox_2=[]
lag_1=[]
lag_2=[]
lag_3=[]
lag_4=[]
lag_5=[]
lag_6=[]
lag_7=[]
lag_8=[]
lag_9=[]
min_pvalue=[]
min_lag=[]
stdev1=[]
stdev2=[]
sector1=[]
sector2=[]
nifty_auto=['MARUTI.NS','APOLLOTYRE.NS','ASHOKLEY.NS','BAJAJ-AUTO.NS','MRF.NS','BOSCHLTD.NS','M&M.NS','EXIDEIND.NS','HEROMOTOCO.NS','TATAMOTORS.NS']
nifty_bank=['AXISBANK.NS','BANKBARODA.NS','FEDERALBNK.NS','HDFCBANK.NS','ICICIBANK.NS','IDFCFIRSTB.NS','INDUSINDBK.NS','SBIN.NS','KOTAKBANK.NS','PNB.NS']
nifty_consumerdurables=['BAJAJELEC.NS','BATAINDIA.NS','BLUESTARCO.NS','CROMPTON.NS','WHIRLPOOL.NS','TITAN.NS','HAVELLS.NS','ORIENTELEC.NS','RELAXO.NS','VGUARD.NS']
nifty_fmcg=['BRITANNIA.NS','COLPAL.NS','DABUR.NS','GODREJCP.NS','GODREJIND.NS','TATACONSUM.NS','ITC.NS','HINDUNILVR.NS','NESTLEIND.NS','PGHH.NS']
nifty_it=['WIPRO.NS','TECHM.NS','TCS.NS','NIITTECH.NS','MINDTREE.NS','INFY.NS','HCLTECH.NS','JUSTDIAL.NS','HEXAWARE.NS','TATAELXSI.NS']
nifty_media=['BALAJITELE.NS','ZEEMEDIA.NS','TV18BRDCST.NS','PVR.NS','NETWORK18.NS','DISHTV.NS','TVTODAY.NS','INOXLEISUR.NS','JAGRAN.NS','SUNTV.NS']
nifty_metal=['APLAPOLLO.NS','COALINDIA.NS','HINDALCO.NS','HINDCOPPER.NS','HINDZINC.NS','JSWSTEEL.NS','TATASTEEL.NS','NATIONALUM.NS','RATNAMANI.NS','WELCORP.NS']
nifty_oilandgas=['ADANIGAS.NS','RELIANCE.NS','OIL.NS','BPCL.NS','HINDPETRO.NS','ONGC.NS','PETRONET.NS','CASTROLIND.NS','IOC.NS','AEGISCHEM.NS']
nifty_pharma=['AUROPHARMA.NS','BIOCON.NS','CADILAHC.NS','CIPLA.NS','DIVISLAB.NS','DRREDDY.NS','GLENMARK.NS','LUPIN.NS','PEL.NS','SUNPHARMA.NS']
nifty_realty=['BRIGADE.NS','DLF.NS','GODREJPROP.NS','IBREALEST.NS','MAHLIFE.NS','OBEROIRLTY.NS','PHOENIXLTD.NS','PRESTIGE.NS','SOBHA.NS','SUNTECK.NS']
list2d = [nifty_auto, nifty_bank, nifty_consumerdurables, nifty_fmcg, nifty_it, nifty_media, nifty_metal, nifty_oilandgas, nifty_pharma, nifty_realty]
Stock_list = list(itertools.chain(*list2d))
new_stock_list=['MSFT','AAPL','AMZN','GOOGL','ORCL','JPM','BRK','GS','AXP','HSBC','V','BAC','T','JNJ','NVS','MRK','UNH','XOM','CVX','TOT','TM','F',
            'NSANY','TSLA','GM','HOG','BA','DAL','LUV','UAL','AAL','SAVE','MCD','CMG','KMX','MUSA','CTB','SAH','GPC','H','LVS','MAR','PFE','PG','CHL',
            'ABT','MDT','WMT','KO','PEP','BABA','NKE','DIS','NFLX','EROS','WWE','CNK','DELL','IBM','HPQ','FIT','HMI','TSM','USEG','PTR','SNP','UNP','SPCE',
            'LMT','NOC','UPS','FDX','RIO','VZ','SAP','UL']
for stock1 in new_stock_list:
  try:
    data1=pdr.DataReader(stock1, data_source='yahoo', start='25/3/2020', end=today)
    data1['Key']=data1.index
  except:
    continue
  
  for stock2 in new_stock_list:
    if (stock1==stock2):
      continue

    #RUNNING THE GRANGER CAUSALITY TEST:
    try:
      data2=pdr.DataReader(stock2, data_source='yahoo', start='25/3/2020', end=today)
      data2['Key']=data2.index
      result=pd.merge(data1, data2, on='Key')
      x1=result['Close_x']
      y1=result['Close_y']
      granger_data=list(zip(x1,y1))
      granger_result=ts.grangercausalitytests(granger_data, maxlag=9) #GRANGER CAUSALITY TEST RESULTS
    except:
      continue

    #STOCK NAME AND SECTOR STORED:
    stox_1.append(stock1)
    stox_2.append(stock2)

    for x_1 in nifty_auto:
      if (x_1==stock1):
        sector1.append('Auto')
    for x_2 in nifty_bank:
      if (x_2==stock1):
        sector1.append('Banking')
    for x_3 in nifty_consumerdurables:
      if (x_3==stock1):
        sector1.append('Consumer Durables')
    for x_4 in nifty_fmcg:
      if (x_4==stock1):
        sector1.append('FMCG')
    for x_5 in nifty_it:
      if (x_5==stock1):
        sector1.append('I.T.')
    for x_6 in nifty_media:
      if (x_6==stock1):
        sector1.append('Media')
    for x_7 in nifty_metal:
      if (x_7==stock1):
        sector1.append('Metal')
    for x_8 in nifty_oilandgas:
      if (x_8==stock1):
        sector1.append('Oil and Gas')
    for x_9 in nifty_pharma:
      if (x_9==stock1):
        sector1.append('Pharma')
    for x_10 in nifty_realty:
      if (x_10==stock1):
        sector1.append('Realty')
    
    for y_1 in nifty_auto:
      if (y_1==stock2):
        sector2.append('Auto')
    for y_2 in nifty_bank:
      if (y_2==stock2):
        sector2.append('Banking')
    for y_3 in nifty_consumerdurables:
      if (y_3==stock2):
        sector2.append('Consumer Durables')
    for y_4 in nifty_fmcg:
      if (y_4==stock2):
        sector2.append('FMCG')
    for y_5 in nifty_it:
      if (y_5==stock2):
        sector2.append('I.T.')
    for y_6 in nifty_media:
      if (y_6==stock2):
        sector2.append('Media')
    for y_7 in nifty_metal:
      if (y_7==stock2):
        sector2.append('Metal')
    for y_8 in nifty_oilandgas:
      if (y_8==stock2):
        sector2.append('Oil and Gas')
    for y_9 in nifty_pharma:
      if (y_9==stock2):
        sector2.append('Pharma')
    for y_10 in nifty_realty:
      if (y_10==stock2):
        sector2.append('Realty')

    #STORING PVALUES IN THE MASTER PVALUES DATAFRAME
    #1––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
    try:
      a1=granger_result[1]
      a1_=a1[0]
      x_params_1=a1_['params_ftest']
      x_likelihhod_ratio_1=a1_['lrtest']
      x_SSR_chi2_1=a1_['ssr_chi2test']
      pvalue1=((x_params_1[1]+x_likelihhod_ratio_1[1]+x_SSR_chi2_1[1])/3) #TEST RESULTS FROM THE 3 GRANGER TESTS HAVE BEEN OBSERVED TO BE LARGELY SIMILAR. WE TAKE AN AVERAGE VALUE, GIVING EQUAL WEIGHTAGE TO EACH TEST
      lag_1.append(pvalue1)
      #2––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
      a2=granger_result[2]
      a2_=a2[0]
      x_params_2=a2_['params_ftest']
      x_likelihhod_ratio_2=a2_['lrtest']
      x_SSR_chi2_2=a2_['ssr_chi2test']
      pvalue2=((x_params_2[1]+x_likelihhod_ratio_2[1]+x_SSR_chi2_2[1])/3) 
      lag_2.append(pvalue2)
      #3––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
      a3=granger_result[3]
      a3_=a3[0]
      x_params_3=a3_['params_ftest']
      x_likelihhod_ratio_3=a3_['lrtest']
      x_SSR_chi2_3=a3_['ssr_chi2test']
      pvalue3=((x_params_3[1]+x_likelihhod_ratio_3[1]+x_SSR_chi2_3[1])/3) 
      lag_3.append(pvalue3)
      #4––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
      a4=granger_result[4]
      a4_=a4[0]
      x_params_4=a4_['params_ftest']
      x_likelihhod_ratio_4=a4_['lrtest']
      x_SSR_chi2_4=a4_['ssr_chi2test']
      pvalue4=((x_params_4[1]+x_likelihhod_ratio_4[1]+x_SSR_chi2_4[1])/3) 
      lag_4.append(pvalue4)
      #5––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
      a5=granger_result[5]
      a5_=a5[0]
      x_params_5=a5_['params_ftest']
      x_likelihhod_ratio_5=a5_['lrtest']
      x_SSR_chi2_5=a5_['ssr_chi2test']
      pvalue5=((x_params_5[1]+x_likelihhod_ratio_5[1]+x_SSR_chi2_5[1])/3) 
      lag_5.append(pvalue5)
      #6––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
      a6=granger_result[6]
      a6_=a6[0]
      x_params_6=a6_['params_ftest']
      x_likelihhod_ratio_6=a6_['lrtest']
      x_SSR_chi2_6=a6_['ssr_chi2test']
      pvalue6=((x_params_6[1]+x_likelihhod_ratio_6[1]+x_SSR_chi2_6[1])/3) 
      lag_6.append(pvalue6)
      #7––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
      a7=granger_result[7]
      a7_=a7[0]
      x_params_7=a7_['params_ftest']
      x_likelihhod_ratio_7=a7_['lrtest']
      x_SSR_chi2_7=a7_['ssr_chi2test']
      pvalue7=((x_params_7[1]+x_likelihhod_ratio_7[1]+x_SSR_chi2_7[1])/3) 
      lag_7.append(pvalue7)
      #8––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
      a8=granger_result[8]
      a8_=a8[0]
      x_params_8=a8_['params_ftest']
      x_likelihhod_ratio_8=a8_['lrtest']
      x_SSR_chi2_8=a8_['ssr_chi2test']
      pvalue8=((x_params_8[1]+x_likelihhod_ratio_8[1]+x_SSR_chi2_8[1])/3) 
      lag_8.append(pvalue8)
      #9––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
      a9=granger_result[9]
      a9_=a9[0]
      x_params_9=a9_['params_ftest']
      x_likelihhod_ratio_9=a9_['lrtest']
      x_SSR_chi2_9=a9_['ssr_chi2test']
      pvalue9=((x_params_9[1]+x_likelihhod_ratio_9[1]+x_SSR_chi2_9[1])/3) 
      lag_9.append(pvalue9)
      #–––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
    except:
      print(stock1)
      print(stock2)
      pvalue1=1
      lag_1.append(pvalue1)
      pvalue2=1
      lag_2.append(pvalue2)
      pvalue3=1
      lag_3.append(pvalue3)
      pvalue4=1
      lag_4.append(pvalue4)
      pvalue5=1
      lag_5.append(pvalue5)
      pvalue6=1
      lag_6.append(pvalue6)
      pvalue7=1
      lag_7.append(pvalue7)
      pvalue8=1
      lag_8.append(pvalue8)
      pvalue9=1
      lag_9.append(pvalue9)

    #MINIMUM P-VALUE
    col_p=[pvalue1,pvalue2,pvalue3,pvalue4,pvalue5,pvalue6,pvalue7,pvalue8,pvalue9]
    min_p=min(col_p)
    min_pvalue.append(min_p)

    #FINDING THE BEST LAG
    for asda in range(len(col_p)):
      if(col_p[asda]==min_p):
        bruh=asda+1
        min_lag.append(bruh)
    
    #INDIVIDUAL STD_DEVIATION DATA: STOCK PRICES ARE NORMALISED SUCH THAT THEY ALL START FROM 0
    try:
      stock1_price = x1.tolist()
      yeet1=np.array(stock1_price)
      stock1_da = (yeet1/stock1_price[0]).tolist()
      val1=stdev(stock1_da)
      stdev1.append(val1)
    except:
      stdev1.append(5.0)

    try:
      stock2_price = y1.tolist()
      yeet2=np.array(stock2_price)
      stock2_da = (yeet2/stock2_price[0]).tolist()
      val2=stdev(stock2_da)
      stdev2.append(val2)
    except:
      stdev2.append(5.0)
dict_master_pvalues_1={'Stock1 code':stox_1,'Sector1':sector1,'Stock2 code':stox_2,'Sector2':sector2,'Min. p':min_pvalue,'Best lag':min_lag,
                     'Std dev1':stdev1,'Std dev2':stdev2}
Master_df_1=pd.DataFrame(data=dict_master_pvalues_1)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.9726  , p=0.0059  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=8.2507  , p=0.0041  , df=1
# likelihood ratio test: chi2=7.8903  , p=0.0050  , df=1
# parameter F test:         F=7.9726  , p=0.0059  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4256  , p=0.2462  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=3.0230  , p=0.2206  , df=2
# likelihood ratio test: chi2=2.9722  , p=0.2262  , df=2
# parameter F test:         F=1.4256  , p=0.2462  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4420  , p=0.2368  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=4.7044  , p=0.1948  , df=3
# likelihood ratio test: chi2=4.5816  , p=0.2051  , df=3
# parameter F test:         F=1.4420  , p=0.2368  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7723  , p=0.5465  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=3.4504  , p=0.4855  , df=4
# likelihood ratio test: chi2=3.3830  , p=0.4959  , df=4
# parameter F test:         F=0.7723  , p=0.5465  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4947  , p=0.7792  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=2.8414  , p=0.7244  , df=5
# likelihood ratio test: chi2=2.7949  , p=0.7316  , df=5
# parameter F test:         F=0.4947  , p=0.7792  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8625  , p=0.5268  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=6.1222  , p=0.4096  , df=6
# likelihood ratio test: chi2=5.9094  , p=0.4334  , df=6
# parameter F test:         F=0.8625  , p=0.5268  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7617  , p=0.6211  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=6.5084  , p=0.4818  , df=7
# likelihood ratio test: chi2=6.2658  , p=0.5091  , df=7
# parameter F test:         F=0.7617  , p=0.6211  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6750  , p=0.7116  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=6.8125  , p=0.5570  , df=8
# likelihood ratio test: chi2=6.5443  , p=0.5865  , df=8
# parameter F test:         F=0.6750  , p=0.7116  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9325  , p=0.5038  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=10.9647 , p=0.2781  , df=9
# likelihood ratio test: chi2=10.2834 , p=0.3280  , df=9
# parameter F test:         F=0.9325  , p=0.5038  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.0787  , p=0.1530  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=2.1513  , p=0.1425  , df=1
# likelihood ratio test: chi2=2.1257  , p=0.1448  , df=1
# parameter F test:         F=2.0787  , p=0.1530  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5495  , p=0.5793  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=1.1652  , p=0.5584  , df=2
# likelihood ratio test: chi2=1.1576  , p=0.5606  , df=2
# parameter F test:         F=0.5495  , p=0.5793  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2473  , p=0.2982  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=4.0692  , p=0.2541  , df=3
# likelihood ratio test: chi2=3.9769  , p=0.2640  , df=3
# parameter F test:         F=1.2473  , p=0.2982  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.2776  , p=0.0685  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=10.1751 , p=0.0376  , df=4
# likelihood ratio test: chi2=9.6168  , p=0.0474  , df=4
# parameter F test:         F=2.2776  , p=0.0685  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.7342  , p=0.1373  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=9.9601  , p=0.0764  , df=5
# likelihood ratio test: chi2=9.4185  , p=0.0935  , df=5
# parameter F test:         F=1.7342  , p=0.1373  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5379  , p=0.1784  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=10.9166 , p=0.0910  , df=6
# likelihood ratio test: chi2=10.2633 , p=0.1140  , df=6
# parameter F test:         F=1.5379  , p=0.1784  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.9066  , p=0.0818  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=16.2906 , p=0.0226  , df=7
# likelihood ratio test: chi2=14.8745 , p=0.0376  , df=7
# parameter F test:         F=1.9066  , p=0.0818  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.7581  , p=0.1018  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=17.7438 , p=0.0232  , df=8
# likelihood ratio test: chi2=16.0626 , p=0.0415  , df=8
# parameter F test:         F=1.7581  , p=0.1018  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.7630  , p=0.0937  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=20.7299 , p=0.0139  , df=9
# likelihood ratio test: chi2=18.4577 , p=0.0302  , df=9
# parameter F test:         F=1.7630  , p=0.0937  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0658  , p=0.7982  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.0681  , p=0.7941  , df=1
# likelihood ratio test: chi2=0.0681  , p=0.7942  , df=1
# parameter F test:         F=0.0658  , p=0.7982  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3123  , p=0.7326  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=0.6623  , p=0.7181  , df=2
# likelihood ratio test: chi2=0.6598  , p=0.7190  , df=2
# parameter F test:         F=0.3123  , p=0.7326  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2524  , p=0.8594  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=0.8236  , p=0.8438  , df=3
# likelihood ratio test: chi2=0.8197  , p=0.8447  , df=3
# parameter F test:         F=0.2524  , p=0.8594  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3592  , p=0.8369  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=1.6046  , p=0.8080  , df=4
# likelihood ratio test: chi2=1.5898  , p=0.8106  , df=4
# parameter F test:         F=0.3592  , p=0.8369  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5174  , p=0.7623  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=2.9718  , p=0.7043  , df=5
# likelihood ratio test: chi2=2.9210  , p=0.7122  , df=5
# parameter F test:         F=0.5174  , p=0.7623  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7465  , p=0.6141  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=5.2992  , p=0.5061  , df=6
# likelihood ratio test: chi2=5.1387  , p=0.5261  , df=6
# parameter F test:         F=0.7465  , p=0.6141  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6438  , p=0.7181  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=5.5011  , p=0.5991  , df=7
# likelihood ratio test: chi2=5.3265  , p=0.6202  , df=7
# parameter F test:         F=0.6438  , p=0.7181  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6640  , p=0.7210  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=6.7014  , p=0.5692  , df=8
# likelihood ratio test: chi2=6.4417  , p=0.5979  , df=8
# parameter F test:         F=0.6640  , p=0.7210  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4705  , p=0.8889  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=5.5316  , p=0.7857  , df=9
# likelihood ratio test: chi2=5.3509  , p=0.8027  , df=9
# parameter F test:         F=0.4705  , p=0.8889  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5430  , p=0.4632  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.5619  , p=0.4535  , df=1
# likelihood ratio test: chi2=0.5601  , p=0.4542  , df=1
# parameter F test:         F=0.5430  , p=0.4632  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0496  , p=0.9516  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=0.1052  , p=0.9488  , df=2
# likelihood ratio test: chi2=0.1051  , p=0.9488  , df=2
# parameter F test:         F=0.0496  , p=0.9516  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.3033  , p=0.0832  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=7.5146  , p=0.0572  , df=3
# likelihood ratio test: chi2=7.2076  , p=0.0656  , df=3
# parameter F test:         F=2.3033  , p=0.0832  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8834  , p=0.4780  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=3.9466  , p=0.4133  , df=4
# likelihood ratio test: chi2=3.8587  , p=0.4255  , df=4
# parameter F test:         F=0.8834  , p=0.4780  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9274  , p=0.4683  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=5.3261  , p=0.3774  , df=5
# likelihood ratio test: chi2=5.1659  , p=0.3960  , df=5
# parameter F test:         F=0.9274  , p=0.4683  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6617  , p=0.6807  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=4.6969  , p=0.5832  , df=6
# likelihood ratio test: chi2=4.5703  , p=0.6000  , df=6
# parameter F test:         F=0.6617  , p=0.6807  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6381  , p=0.7228  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=5.4516  , p=0.6050  , df=7
# likelihood ratio test: chi2=5.2800  , p=0.6258  , df=7
# parameter F test:         F=0.6381  , p=0.7228  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7276  , p=0.6666  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=7.3427  , p=0.5001  , df=8
# likelihood ratio test: chi2=7.0324  , p=0.5331  , df=8
# parameter F test:         F=0.7276  , p=0.6666  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6986  , p=0.7076  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=8.2144  , p=0.5127  , df=9
# likelihood ratio test: chi2=7.8241  , p=0.5520  , df=9
# parameter F test:         F=0.6986  , p=0.7076  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0314  , p=0.8599  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.0325  , p=0.8570  , df=1
# likelihood ratio test: chi2=0.0325  , p=0.8570  , df=1
# parameter F test:         F=0.0314  , p=0.8599  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.7519  , p=0.1798  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=3.7148  , p=0.1561  , df=2
# likelihood ratio test: chi2=3.6386  , p=0.1621  , df=2
# parameter F test:         F=1.7519  , p=0.1798  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6524  , p=0.1840  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=5.3908  , p=0.1453  , df=3
# likelihood ratio test: chi2=5.2304  , p=0.1557  , df=3
# parameter F test:         F=1.6524  , p=0.1840  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8887  , p=0.4749  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=3.9701  , p=0.4101  , df=4
# likelihood ratio test: chi2=3.8812  , p=0.4223  , df=4
# parameter F test:         F=0.8887  , p=0.4749  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5473  , p=0.7398  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=3.1432  , p=0.6779  , df=5
# likelihood ratio test: chi2=3.0865  , p=0.6867  , df=5
# parameter F test:         F=0.5473  , p=0.7398  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6547  , p=0.6862  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=4.6474  , p=0.5898  , df=6
# likelihood ratio test: chi2=4.5234  , p=0.6062  , df=6
# parameter F test:         F=0.6547  , p=0.6862  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5502  , p=0.7933  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=4.7008  , p=0.6964  , df=7
# likelihood ratio test: chi2=4.5725  , p=0.7120  , df=7
# parameter F test:         F=0.5502  , p=0.7933  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9188  , p=0.5069  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=9.2729  , p=0.3198  , df=8
# likelihood ratio test: chi2=8.7851  , p=0.3607  , df=8
# parameter F test:         F=0.9188  , p=0.5069  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7897  , p=0.6268  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=9.2851  , p=0.4114  , df=9
# likelihood ratio test: chi2=8.7904  , p=0.4568  , df=9
# parameter F test:         F=0.7897  , p=0.6268  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4549  , p=0.5018  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.4708  , p=0.4926  , df=1
# likelihood ratio test: chi2=0.4696  , p=0.4932  , df=1
# parameter F test:         F=0.4549  , p=0.5018  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6532  , p=0.5230  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=1.3851  , p=0.5003  , df=2
# likelihood ratio test: chi2=1.3744  , p=0.5030  , df=2
# parameter F test:         F=0.6532  , p=0.5230  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7720  , p=0.5130  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=2.5188  , p=0.4719  , df=3
# likelihood ratio test: chi2=2.4830  , p=0.4784  , df=3
# parameter F test:         F=0.7720  , p=0.5130  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7051  , p=0.5909  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=3.1500  , p=0.5330  , df=4
# likelihood ratio test: chi2=3.0937  , p=0.5423  , df=4
# parameter F test:         F=0.7051  , p=0.5909  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5039  , p=0.7724  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=2.8942  , p=0.7163  , df=5
# likelihood ratio test: chi2=2.8460  , p=0.7237  , df=5
# parameter F test:         F=0.5039  , p=0.7724  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3974  , p=0.8784  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=2.8207  , p=0.8310  , df=6
# likelihood ratio test: chi2=2.7744  , p=0.8366  , df=6
# parameter F test:         F=0.3974  , p=0.8784  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3472  , p=0.9290  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=2.9669  , p=0.8881  , df=7
# likelihood ratio test: chi2=2.9151  , p=0.8927  , df=7
# parameter F test:         F=0.3472  , p=0.9290  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6232  , p=0.7553  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=6.2900  , p=0.6148  , df=8
# likelihood ratio test: chi2=6.0604  , p=0.6405  , df=8
# parameter F test:         F=0.6232  , p=0.7553  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8209  , p=0.5992  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=9.6520  , p=0.3794  , df=9
# likelihood ratio test: chi2=9.1189  , p=0.4264  , df=9
# parameter F test:         F=0.8209  , p=0.5992  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2343  , p=0.6296  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.2425  , p=0.6224  , df=1
# likelihood ratio test: chi2=0.2422  , p=0.6226  , df=1
# parameter F test:         F=0.2343  , p=0.6296  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3623  , p=0.6972  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=0.7683  , p=0.6810  , df=2
# likelihood ratio test: chi2=0.7649  , p=0.6822  , df=2
# parameter F test:         F=0.3623  , p=0.6972  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4239  , p=0.7364  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=1.3831  , p=0.7095  , df=3
# likelihood ratio test: chi2=1.3722  , p=0.7121  , df=3
# parameter F test:         F=0.4239  , p=0.7364  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4246  , p=0.7904  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=1.8968  , p=0.7547  , df=4
# likelihood ratio test: chi2=1.8762  , p=0.7585  , df=4
# parameter F test:         F=0.4246  , p=0.7904  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5345  , p=0.7494  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=3.0700  , p=0.6892  , df=5
# likelihood ratio test: chi2=3.0159  , p=0.6975  , df=5
# parameter F test:         F=0.5345  , p=0.7494  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6428  , p=0.6956  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=4.5629  , p=0.6010  , df=6
# likelihood ratio test: chi2=4.4433  , p=0.6169  , df=6
# parameter F test:         F=0.6428  , p=0.6956  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5727  , p=0.7756  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=4.8936  , p=0.6729  , df=7
# likelihood ratio test: chi2=4.7548  , p=0.6899  , df=7
# parameter F test:         F=0.5727  , p=0.7756  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9665  , p=0.4698  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=9.7546  , p=0.2827  , df=8
# likelihood ratio test: chi2=9.2167  , p=0.3243  , df=8
# parameter F test:         F=0.9665  , p=0.4698  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7446  , p=0.6668  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=8.7552  , p=0.4602  , df=9
# likelihood ratio test: chi2=8.3136  , p=0.5029  , df=9
# parameter F test:         F=0.7446  , p=0.6668  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.3347  , p=0.0713  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=3.4511  , p=0.0632  , df=1
# likelihood ratio test: chi2=3.3858  , p=0.0658  , df=1
# parameter F test:         F=3.3347  , p=0.0713  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.0609  , p=0.3508  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=2.2497  , p=0.3247  , df=2
# likelihood ratio test: chi2=2.2214  , p=0.3293  , df=2
# parameter F test:         F=1.0609  , p=0.3508  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1244  , p=0.3442  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=3.6685  , p=0.2996  , df=3
# likelihood ratio test: chi2=3.5933  , p=0.3089  , df=3
# parameter F test:         F=1.1244  , p=0.3442  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3664  , p=0.2534  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=6.1044  , p=0.1915  , df=4
# likelihood ratio test: chi2=5.8975  , p=0.2069  , df=4
# parameter F test:         F=1.3664  , p=0.2534  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8705  , p=0.5052  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=4.9994  , p=0.4160  , df=5
# likelihood ratio test: chi2=4.8579  , p=0.4335  , df=5
# parameter F test:         F=0.8705  , p=0.5052  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4896  , p=0.8141  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=3.4752  , p=0.7473  , df=6
# likelihood ratio test: chi2=3.4052  , p=0.7565  , df=6
# parameter F test:         F=0.4896  , p=0.8141  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3596  , p=0.9224  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=3.0728  , p=0.8782  , df=7
# likelihood ratio test: chi2=3.0173  , p=0.8834  , df=7
# parameter F test:         F=0.3596  , p=0.9224  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.2793  , p=0.9705  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=2.8189  , p=0.9452  , df=8
# likelihood ratio test: chi2=2.7716  , p=0.9479  , df=8
# parameter F test:         F=0.2793  , p=0.9705  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6484  , p=0.7513  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=7.6241  , p=0.5724  , df=9
# likelihood ratio test: chi2=7.2863  , p=0.6073  , df=9
# parameter F test:         F=0.6484  , p=0.7513  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0106  , p=0.9183  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.0110  , p=0.9166  , df=1
# likelihood ratio test: chi2=0.0110  , p=0.9166  , df=1
# parameter F test:         F=0.0106  , p=0.9183  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7822  , p=0.4608  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=1.6586  , p=0.4364  , df=2
# likelihood ratio test: chi2=1.6431  , p=0.4397  , df=2
# parameter F test:         F=0.7822  , p=0.4608  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7382  , p=0.5323  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=2.4085  , p=0.4921  , df=3
# likelihood ratio test: chi2=2.3758  , p=0.4982  , df=3
# parameter F test:         F=0.7382  , p=0.5323  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9770  , p=0.4252  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=4.3646  , p=0.3589  , df=4
# likelihood ratio test: chi2=4.2574  , p=0.3723  , df=4
# parameter F test:         F=0.9770  , p=0.4252  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7713  , p=0.5735  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=4.4296  , p=0.4894  , df=5
# likelihood ratio test: chi2=4.3180  , p=0.5046  , df=5
# parameter F test:         F=0.7713  , p=0.5735  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7319  , p=0.6255  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=5.1954  , p=0.5190  , df=6
# likelihood ratio test: chi2=5.0410  , p=0.5386  , df=6
# parameter F test:         F=0.7319  , p=0.6255  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8029  , p=0.5877  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=6.8600  , p=0.4436  , df=7
# likelihood ratio test: chi2=6.5912  , p=0.4726  , df=7
# parameter F test:         F=0.8029  , p=0.5877  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0948  , p=0.3783  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=11.0493 , p=0.1989  , df=8
# likelihood ratio test: chi2=10.3656 , p=0.2403  , df=8
# parameter F test:         F=1.0948  , p=0.3783  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8735  , p=0.5534  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=10.2711 , p=0.3290  , df=9
# likelihood ratio test: chi2=9.6702  , p=0.3778  , df=9
# parameter F test:         F=0.8735  , p=0.5534  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0007  , p=0.9796  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.0007  , p=0.9792  , df=1
# likelihood ratio test: chi2=0.0007  , p=0.9792  , df=1
# parameter F test:         F=0.0007  , p=0.9796  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6412  , p=0.5293  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=1.3596  , p=0.5067  , df=2
# likelihood ratio test: chi2=1.3492  , p=0.5094  , df=2
# parameter F test:         F=0.6412  , p=0.5293  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5855  , p=0.6262  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=1.9102  , p=0.5912  , df=3
# likelihood ratio test: chi2=1.8896  , p=0.5956  , df=3
# parameter F test:         F=0.5855  , p=0.6262  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4685  , p=0.7587  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=2.0930  , p=0.7187  , df=4
# likelihood ratio test: chi2=2.0680  , p=0.7233  , df=4
# parameter F test:         F=0.4685  , p=0.7587  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3863  , p=0.8567  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=2.2188  , p=0.8181  , df=5
# likelihood ratio test: chi2=2.1904  , p=0.8222  , df=5
# parameter F test:         F=0.3863  , p=0.8567  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3207  , p=0.9241  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=2.2766  , p=0.8926  , df=6
# likelihood ratio test: chi2=2.2463  , p=0.8957  , df=6
# parameter F test:         F=0.3207  , p=0.9241  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.2725  , p=0.9626  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=2.3280  , p=0.9395  , df=7
# likelihood ratio test: chi2=2.2959  , p=0.9417  , df=7
# parameter F test:         F=0.2725  , p=0.9626  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.4164  , p=0.9071  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=4.2025  , p=0.8384  , df=8
# likelihood ratio test: chi2=4.0984  , p=0.8481  , df=8
# parameter F test:         F=0.4164  , p=0.9071  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4136  , p=0.9232  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=4.8631  , p=0.8461  , df=9
# likelihood ratio test: chi2=4.7227  , p=0.8578  , df=9
# parameter F test:         F=0.4136  , p=0.9232  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3234  , p=0.2532  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=1.3696  , p=0.2419  , df=1
# likelihood ratio test: chi2=1.3591  , p=0.2437  , df=1
# parameter F test:         F=1.3234  , p=0.2532  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6561  , p=0.5215  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=1.3913  , p=0.4988  , df=2
# likelihood ratio test: chi2=1.3804  , p=0.5015  , df=2
# parameter F test:         F=0.6561  , p=0.5215  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4537  , p=0.2335  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=4.7426  , p=0.1916  , df=3
# likelihood ratio test: chi2=4.6179  , p=0.2020  , df=3
# parameter F test:         F=1.4537  , p=0.2335  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7782  , p=0.5428  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=3.4764  , p=0.4815  , df=4
# likelihood ratio test: chi2=3.4080  , p=0.4920  , df=4
# parameter F test:         F=0.7782  , p=0.5428  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5703  , p=0.7225  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=3.2755  , p=0.6576  , df=5
# likelihood ratio test: chi2=3.2139  , p=0.6670  , df=5
# parameter F test:         F=0.5703  , p=0.7225  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5416  , p=0.7748  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=3.8449  , p=0.6977  , df=6
# likelihood ratio test: chi2=3.7595  , p=0.7092  , df=6
# parameter F test:         F=0.5416  , p=0.7748  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4135  , p=0.8908  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=3.5328  , p=0.8317  , df=7
# likelihood ratio test: chi2=3.4597  , p=0.8395  , df=7
# parameter F test:         F=0.4135  , p=0.8908  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5175  , p=0.8391  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=5.2225  , p=0.7335  , df=8
# likelihood ratio test: chi2=5.0630  , p=0.7508  , df=8
# parameter F test:         F=0.5175  , p=0.8391  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5205  , p=0.8543  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=6.1196  , p=0.7279  , df=9
# likelihood ratio test: chi2=5.8994  , p=0.7499  , df=9
# parameter F test:         F=0.5205  , p=0.8543  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.3428  , p=0.1295  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=2.4245  , p=0.1194  , df=1
# likelihood ratio test: chi2=2.3921  , p=0.1220  , df=1
# parameter F test:         F=2.3428  , p=0.1295  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9366  , p=0.3961  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=1.9860  , p=0.3705  , df=2
# likelihood ratio test: chi2=1.9639  , p=0.3746  , df=2
# parameter F test:         F=0.9366  , p=0.3961  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1483  , p=0.3348  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=3.7465  , p=0.2902  , df=3
# likelihood ratio test: chi2=3.6681  , p=0.2996  , df=3
# parameter F test:         F=1.1483  , p=0.3348  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4032  , p=0.8058  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=1.8013  , p=0.7723  , df=4
# likelihood ratio test: chi2=1.7827  , p=0.7757  , df=4
# parameter F test:         F=0.4032  , p=0.8058  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0704  , p=0.3838  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=6.1474  , p=0.2921  , df=5
# likelihood ratio test: chi2=5.9353  , p=0.3126  , df=5
# parameter F test:         F=1.0704  , p=0.3838  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5203  , p=0.1840  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=10.7919 , p=0.0950  , df=6
# likelihood ratio test: chi2=10.1529 , p=0.1184  , df=6
# parameter F test:         F=1.5203  , p=0.1840  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6721  , p=0.1306  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=14.2870 , p=0.0463  , df=7
# likelihood ratio test: chi2=13.1825 , p=0.0678  , df=7
# parameter F test:         F=1.6721  , p=0.1306  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.8644  , p=0.0810  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=18.8159 , p=0.0159  , df=8
# likelihood ratio test: chi2=16.9393 , p=0.0307  , df=8
# parameter F test:         F=1.8644  , p=0.0810  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6957  , p=0.1092  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=19.9376 , p=0.0183  , df=9
# likelihood ratio test: chi2=17.8243 , p=0.0373  , df=9
# parameter F test:         F=1.6957  , p=0.1092  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.0020  , p=0.3196  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=1.0370  , p=0.3085  , df=1
# likelihood ratio test: chi2=1.0310  , p=0.3099  , df=1
# parameter F test:         F=1.0020  , p=0.3196  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0410  , p=0.9598  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=0.0869  , p=0.9575  , df=2
# likelihood ratio test: chi2=0.0869  , p=0.9575  , df=2
# parameter F test:         F=0.0410  , p=0.9598  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1031  , p=0.9580  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=0.3364  , p=0.9530  , df=3
# likelihood ratio test: chi2=0.3358  , p=0.9532  , df=3
# parameter F test:         F=0.1031  , p=0.9580  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0609  , p=0.9930  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=0.2722  , p=0.9915  , df=4
# likelihood ratio test: chi2=0.2718  , p=0.9916  , df=4
# parameter F test:         F=0.0609  , p=0.9930  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.1204  , p=0.9875  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=0.6917  , p=0.9834  , df=5
# likelihood ratio test: chi2=0.6889  , p=0.9836  , df=5
# parameter F test:         F=0.1204  , p=0.9875  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3246  , p=0.9220  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=2.3045  , p=0.8897  , df=6
# likelihood ratio test: chi2=2.2734  , p=0.8929  , df=6
# parameter F test:         F=0.3246  , p=0.9220  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.2617  , p=0.9665  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=2.2359  , p=0.9456  , df=7
# likelihood ratio test: chi2=2.2063  , p=0.9475  , df=7
# parameter F test:         F=0.2617  , p=0.9665  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.2920  , p=0.9663  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=2.9466  , p=0.9377  , df=8
# likelihood ratio test: chi2=2.8949  , p=0.9408  , df=8
# parameter F test:         F=0.2920  , p=0.9663  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6099  , p=0.7839  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=7.1713  , p=0.6193  , df=9
# likelihood ratio test: chi2=6.8715  , p=0.6505  , df=9
# parameter F test:         F=0.6099  , p=0.7839  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.7365  , p=0.0565  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=3.8669  , p=0.0492  , df=1
# likelihood ratio test: chi2=3.7852  , p=0.0517  , df=1
# parameter F test:         F=3.7365  , p=0.0565  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3741  , p=0.0994  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=5.0342  , p=0.0807  , df=2
# likelihood ratio test: chi2=4.8955  , p=0.0865  , df=2
# parameter F test:         F=2.3741  , p=0.0994  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.5640  , p=0.0605  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=8.3650  , p=0.0390  , df=3
# likelihood ratio test: chi2=7.9869  , p=0.0463  , df=3
# parameter F test:         F=2.5640  , p=0.0605  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3747  , p=0.2505  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=6.1416  , p=0.1888  , df=4
# likelihood ratio test: chi2=5.9322  , p=0.2043  , df=4
# parameter F test:         F=1.3747  , p=0.2505  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0622  , p=0.3883  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=6.1006  , p=0.2966  , df=5
# likelihood ratio test: chi2=5.8916  , p=0.3169  , df=5
# parameter F test:         F=1.0622  , p=0.3883  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5522  , p=0.1740  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=11.0181 , p=0.0878  , df=6
# likelihood ratio test: chi2=10.3530 , p=0.1106  , df=6
# parameter F test:         F=1.5522  , p=0.1740  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6831  , p=0.1278  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=14.3810 , p=0.0448  , df=7
# likelihood ratio test: chi2=13.2626 , p=0.0660  , df=7
# parameter F test:         F=1.6831  , p=0.1278  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.6062  , p=0.1403  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=16.2103 , p=0.0395  , df=8
# likelihood ratio test: chi2=14.7922 , p=0.0633  , df=8
# parameter F test:         F=1.6062  , p=0.1403  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2540  , p=0.2800  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=14.7448 , p=0.0982  , df=9
# likelihood ratio test: chi2=13.5462 , p=0.1394  , df=9
# parameter F test:         F=1.2540  , p=0.2800  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3546  , p=0.5531  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.3669  , p=0.5447  , df=1
# likelihood ratio test: chi2=0.3662  , p=0.5451  , df=1
# parameter F test:         F=0.3546  , p=0.5531  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1308  , p=0.8776  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=0.2773  , p=0.8705  , df=2
# likelihood ratio test: chi2=0.2769  , p=0.8707  , df=2
# parameter F test:         F=0.1308  , p=0.8776  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4884  , p=0.6913  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=1.5935  , p=0.6609  , df=3
# likelihood ratio test: chi2=1.5791  , p=0.6641  , df=3
# parameter F test:         F=0.4884  , p=0.6913  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2589  , p=0.9034  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=1.1566  , p=0.8852  , df=4
# likelihood ratio test: chi2=1.1489  , p=0.8864  , df=4
# parameter F test:         F=0.2589  , p=0.9034  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3035  , p=0.9093  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=1.7428  , p=0.8835  , df=5
# likelihood ratio test: chi2=1.7252  , p=0.8857  , df=5
# parameter F test:         F=0.3035  , p=0.9093  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5202  , p=0.7911  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=3.6929  , p=0.7181  , df=6
# likelihood ratio test: chi2=3.6141  , p=0.7287  , df=6
# parameter F test:         F=0.5202  , p=0.7911  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5320  , p=0.8073  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=4.5456  , p=0.7152  , df=7
# likelihood ratio test: chi2=4.4255  , p=0.7297  , df=7
# parameter F test:         F=0.5320  , p=0.8073  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5859  , p=0.7859  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=5.9131  , p=0.6570  , df=8
# likelihood ratio test: chi2=5.7096  , p=0.6797  , df=8
# parameter F test:         F=0.5859  , p=0.7859  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5433  , p=0.1530  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=18.1457 , p=0.0335  , df=9
# likelihood ratio test: chi2=16.3734 , p=0.0595  , df=9
# parameter F test:         F=1.5433  , p=0.1530  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0002  , p=0.9883  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.0002  , p=0.9881  , df=1
# likelihood ratio test: chi2=0.0002  , p=0.9881  , df=1
# parameter F test:         F=0.0002  , p=0.9883  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2785  , p=0.7576  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=0.5905  , p=0.7444  , df=2
# likelihood ratio test: chi2=0.5885  , p=0.7451  , df=2
# parameter F test:         F=0.2785  , p=0.7576  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1769  , p=0.9118  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=0.5771  , p=0.9016  , df=3
# likelihood ratio test: chi2=0.5752  , p=0.9021  , df=3
# parameter F test:         F=0.1769  , p=0.9118  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2546  , p=0.9060  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=1.1376  , p=0.8883  , df=4
# likelihood ratio test: chi2=1.1301  , p=0.8895  , df=4
# parameter F test:         F=0.2546  , p=0.9060  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3050  , p=0.9084  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=1.7517  , p=0.8823  , df=5
# likelihood ratio test: chi2=1.7339  , p=0.8846  , df=5
# parameter F test:         F=0.3050  , p=0.9084  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.1953  , p=0.9772  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=1.3860  , p=0.9667  , df=6
# likelihood ratio test: chi2=1.3747  , p=0.9674  , df=6
# parameter F test:         F=0.1953  , p=0.9772  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.1580  , p=0.9923  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=1.3501  , p=0.9871  , df=7
# likelihood ratio test: chi2=1.3392  , p=0.9874  , df=7
# parameter F test:         F=0.1580  , p=0.9923  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.2411  , p=0.9814  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=2.4331  , p=0.9648  , df=8
# likelihood ratio test: chi2=2.3977  , p=0.9663  , df=8
# parameter F test:         F=0.2411  , p=0.9814  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.3647  , p=0.9475  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=4.2885  , p=0.8914  , df=9
# likelihood ratio test: chi2=4.1788  , p=0.8993  , df=9
# parameter F test:         F=0.3647  , p=0.9475  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1949  , p=0.6599  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.2017  , p=0.6533  , df=1
# likelihood ratio test: chi2=0.2015  , p=0.6535  , df=1
# parameter F test:         F=0.1949  , p=0.6599  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4106  , p=0.6646  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=0.8706  , p=0.6471  , df=2
# likelihood ratio test: chi2=0.8663  , p=0.6485  , df=2
# parameter F test:         F=0.4106  , p=0.6646  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2221  , p=0.8808  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=0.7247  , p=0.8674  , df=3
# likelihood ratio test: chi2=0.7217  , p=0.8681  , df=3
# parameter F test:         F=0.2221  , p=0.8808  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0933  , p=0.9843  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=0.4168  , p=0.9811  , df=4
# likelihood ratio test: chi2=0.4158  , p=0.9812  , df=4
# parameter F test:         F=0.0933  , p=0.9843  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.1174  , p=0.9882  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=0.6743  , p=0.9844  , df=5
# likelihood ratio test: chi2=0.6716  , p=0.9845  , df=5
# parameter F test:         F=0.1174  , p=0.9882  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3117  , p=0.9289  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=2.2124  , p=0.8992  , df=6
# likelihood ratio test: chi2=2.1838  , p=0.9020  , df=6
# parameter F test:         F=0.3117  , p=0.9289  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3234  , p=0.9409  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=2.7628  , p=0.9060  , df=7
# likelihood ratio test: chi2=2.7178  , p=0.9098  , df=7
# parameter F test:         F=0.3234  , p=0.9409  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.3109  , p=0.9593  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=3.1375  , p=0.9254  , df=8
# likelihood ratio test: chi2=3.0789  , p=0.9293  , df=8
# parameter F test:         F=0.3109  , p=0.9593  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4438  , p=0.9057  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=5.2180  , p=0.8149  , df=9
# likelihood ratio test: chi2=5.0568  , p=0.8293  , df=9
# parameter F test:         F=0.4438  , p=0.9057  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5006  , p=0.4812  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.5180  , p=0.4717  , df=1
# likelihood ratio test: chi2=0.5165  , p=0.4723  , df=1
# parameter F test:         F=0.5006  , p=0.4812  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.0182  , p=0.3657  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=2.1591  , p=0.3398  , df=2
# likelihood ratio test: chi2=2.1330  , p=0.3442  , df=2
# parameter F test:         F=1.0182  , p=0.3657  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1610  , p=0.3299  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=3.7879  , p=0.2853  , df=3
# likelihood ratio test: chi2=3.7078  , p=0.2948  , df=3
# parameter F test:         F=1.1610  , p=0.3299  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0726  , p=0.3759  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=4.7918  , p=0.3093  , df=4
# likelihood ratio test: chi2=4.6630  , p=0.3236  , df=4
# parameter F test:         F=1.0726  , p=0.3759  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0869  , p=0.3748  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=6.2426  , p=0.2833  , df=5
# likelihood ratio test: chi2=6.0240  , p=0.3039  , df=5
# parameter F test:         F=1.0869  , p=0.3748  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9354  , p=0.4752  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=6.6403  , p=0.3554  , df=6
# likelihood ratio test: chi2=6.3909  , p=0.3809  , df=6
# parameter F test:         F=0.9354  , p=0.4752  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8188  , p=0.5750  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=6.9957  , p=0.4293  , df=7
# likelihood ratio test: chi2=6.7165  , p=0.4590  , df=7
# parameter F test:         F=0.8188  , p=0.5750  , df_denom=68, df_num=7
#
# ...
# parameter F test:         F=8.3741  , p=0.0048  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5541  , p=0.2175  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=3.2954  , p=0.1925  , df=2
# likelihood ratio test: chi2=3.2352  , p=0.1984  , df=2
# parameter F test:         F=1.5541  , p=0.2175  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8903  , p=0.1379  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=6.1670  , p=0.1038  , df=3
# likelihood ratio test: chi2=5.9582  , p=0.1137  , df=3
# parameter F test:         F=1.8903  , p=0.1379  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0025  , p=0.4116  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=4.4786  , p=0.3451  , df=4
# likelihood ratio test: chi2=4.3659  , p=0.3587  , df=4
# parameter F test:         F=1.0025  , p=0.4116  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5477  , p=0.7395  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=3.1457  , p=0.6775  , df=5
# likelihood ratio test: chi2=3.0889  , p=0.6863  , df=5
# parameter F test:         F=0.5477  , p=0.7395  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8947  , p=0.5036  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=6.3514  , p=0.3850  , df=6
# likelihood ratio test: chi2=6.1227  , p=0.4096  , df=6
# parameter F test:         F=0.8947  , p=0.5036  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1000  , p=0.3732  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=9.3990  , p=0.2253  , df=7
# likelihood ratio test: chi2=8.9038  , p=0.2596  , df=7
# parameter F test:         F=1.1000  , p=0.3732  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2090  , p=0.3079  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=12.2014 , p=0.1424  , df=8
# likelihood ratio test: chi2=11.3747 , p=0.1814  , df=8
# parameter F test:         F=1.2090  , p=0.3079  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1128  , p=0.3674  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=13.0842 , p=0.1588  , df=9
# likelihood ratio test: chi2=12.1291 , p=0.2061  , df=9
# parameter F test:         F=1.1128  , p=0.3674  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6112  , p=0.4365  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.6325  , p=0.4264  , df=1
# likelihood ratio test: chi2=0.6302  , p=0.4273  , df=1
# parameter F test:         F=0.6112  , p=0.4365  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9573  , p=0.3881  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=2.0299  , p=0.3624  , df=2
# likelihood ratio test: chi2=2.0068  , p=0.3666  , df=2
# parameter F test:         F=0.9573  , p=0.3881  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6407  , p=0.5911  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=2.0902  , p=0.5539  , df=3
# likelihood ratio test: chi2=2.0655  , p=0.5589  , df=3
# parameter F test:         F=0.6407  , p=0.5911  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5980  , p=0.6652  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=2.6715  , p=0.6142  , df=4
# likelihood ratio test: chi2=2.6308  , p=0.6214  , df=4
# parameter F test:         F=0.5980  , p=0.6652  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6129  , p=0.6903  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=3.5198  , p=0.6204  , df=5
# likelihood ratio test: chi2=3.4489  , p=0.6311  , df=5
# parameter F test:         F=0.6129  , p=0.6903  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3193  , p=0.9249  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=2.2666  , p=0.8936  , df=6
# likelihood ratio test: chi2=2.2365  , p=0.8967  , df=6
# parameter F test:         F=0.3193  , p=0.9249  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3356  , p=0.9349  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=2.8676  , p=0.8970  , df=7
# likelihood ratio test: chi2=2.8192  , p=0.9012  , df=7
# parameter F test:         F=0.3356  , p=0.9349  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.3258  , p=0.9532  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=3.2883  , p=0.9150  , df=8
# likelihood ratio test: chi2=3.2240  , p=0.9195  , df=8
# parameter F test:         F=0.3258  , p=0.9532  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5959  , p=0.7955  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=7.0069  , p=0.6364  , df=9
# likelihood ratio test: chi2=6.7202  , p=0.6662  , df=9
# parameter F test:         F=0.5959  , p=0.7955  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4465  , p=0.5058  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.4621  , p=0.4967  , df=1
# likelihood ratio test: chi2=0.4609  , p=0.4972  , df=1
# parameter F test:         F=0.4465  , p=0.5058  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7860  , p=0.4590  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=1.6668  , p=0.4346  , df=2
# likelihood ratio test: chi2=1.6512  , p=0.4380  , df=2
# parameter F test:         F=0.7860  , p=0.4590  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6140  , p=0.1927  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=5.2657  , p=0.1533  , df=3
# likelihood ratio test: chi2=5.1125  , p=0.1637  , df=3
# parameter F test:         F=1.6140  , p=0.1927  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9854  , p=0.1051  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=8.8697  , p=0.0644  , df=4
# likelihood ratio test: chi2=8.4415  , p=0.0767  , df=4
# parameter F test:         F=1.9854  , p=0.1051  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.2061  , p=0.0626  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=12.6703 , p=0.0267  , df=5
# likelihood ratio test: chi2=11.8104 , p=0.0375  , df=5
# parameter F test:         F=2.2061  , p=0.0626  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0353  , p=0.0721  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=14.4478 , p=0.0250  , df=6
# likelihood ratio test: chi2=13.3316 , p=0.0381  , df=6
# parameter F test:         F=2.0353  , p=0.0721  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.7827  , p=0.1050  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=15.2315 , p=0.0331  , df=7
# likelihood ratio test: chi2=13.9844 , p=0.0515  , df=7
# parameter F test:         F=1.7827  , p=0.1050  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.8385  , p=0.0857  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=18.5547 , p=0.0174  , df=8
# likelihood ratio test: chi2=16.7266 , p=0.0331  , df=8
# parameter F test:         F=1.8385  , p=0.0857  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.9206  , p=0.0653  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=22.5824 , p=0.0072  , df=9
# likelihood ratio test: chi2=19.9194 , p=0.0184  , df=9
# parameter F test:         F=1.9206  , p=0.0653  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.0357  , p=0.3117  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=1.0718  , p=0.3005  , df=1
# likelihood ratio test: chi2=1.0654  , p=0.3020  , df=1
# parameter F test:         F=1.0357  , p=0.3117  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5371  , p=0.5865  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=1.1389  , p=0.5658  , df=2
# likelihood ratio test: chi2=1.1316  , p=0.5679  , df=2
# parameter F test:         F=0.5371  , p=0.5865  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2737  , p=0.8442  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=0.8928  , p=0.8272  , df=3
# likelihood ratio test: chi2=0.8882  , p=0.8283  , df=3
# parameter F test:         F=0.2737  , p=0.8442  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2330  , p=0.9190  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=1.0409  , p=0.9035  , df=4
# likelihood ratio test: chi2=1.0346  , p=0.9045  , df=4
# parameter F test:         F=0.2330  , p=0.9190  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4595  , p=0.8051  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=2.6390  , p=0.7554  , df=5
# likelihood ratio test: chi2=2.5989  , p=0.7615  , df=5
# parameter F test:         F=0.4595  , p=0.8051  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4764  , p=0.8237  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=3.3817  , p=0.7596  , df=6
# likelihood ratio test: chi2=3.3154  , p=0.7683  , df=6
# parameter F test:         F=0.4764  , p=0.8237  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4648  , p=0.8566  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=3.9712  , p=0.7831  , df=7
# likelihood ratio test: chi2=3.8791  , p=0.7936  , df=7
# parameter F test:         F=0.4648  , p=0.8566  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.4704  , p=0.8726  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=4.7472  , p=0.7842  , df=8
# likelihood ratio test: chi2=4.6149  , p=0.7978  , df=8
# parameter F test:         F=0.4704  , p=0.8726  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4957  , p=0.8720  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=5.8279  , p=0.7570  , df=9
# likelihood ratio test: chi2=5.6278  , p=0.7765  , df=9
# parameter F test:         F=0.4957  , p=0.8720  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.6684  , p=0.1060  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=2.7615  , p=0.0966  , df=1
# likelihood ratio test: chi2=2.7195  , p=0.0991  , df=1
# parameter F test:         F=2.6684  , p=0.1060  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5394  , p=0.5852  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=1.1437  , p=0.5645  , df=2
# likelihood ratio test: chi2=1.1363  , p=0.5666  , df=2
# parameter F test:         F=0.5394  , p=0.5852  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2171  , p=0.3090  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=3.9708  , p=0.2646  , df=3
# likelihood ratio test: chi2=3.8829  , p=0.2744  , df=3
# parameter F test:         F=1.2171  , p=0.3090  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5262  , p=0.7168  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=2.3509  , p=0.6715  , df=4
# likelihood ratio test: chi2=2.3193  , p=0.6773  , df=4
# parameter F test:         F=0.5262  , p=0.7168  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8315  , p=0.5314  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=4.7756  , p=0.4439  , df=5
# likelihood ratio test: chi2=4.6463  , p=0.4606  , df=5
# parameter F test:         F=0.8315  , p=0.5314  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7308  , p=0.6264  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=5.1877  , p=0.5200  , df=6
# likelihood ratio test: chi2=5.0338  , p=0.5395  , df=6
# parameter F test:         F=0.7308  , p=0.6264  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7356  , p=0.6425  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=6.2854  , p=0.5069  , df=7
# likelihood ratio test: chi2=6.0587  , p=0.5329  , df=7
# parameter F test:         F=0.7356  , p=0.6425  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7711  , p=0.6293  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=7.7820  , p=0.4550  , df=8
# likelihood ratio test: chi2=7.4346  , p=0.4906  , df=8
# parameter F test:         F=0.7711  , p=0.6293  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4489  , p=0.9026  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=5.2786  , p=0.8094  , df=9
# likelihood ratio test: chi2=5.1137  , p=0.8243  , df=9
# parameter F test:         F=0.4489  , p=0.9026  , df_denom=62, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8239  , p=0.3666  , df_denom=86, df_num=1
# ssr based chi2 test:   chi2=0.8527  , p=0.3558  , df=1
# likelihood ratio test: chi2=0.8486  , p=0.3569  , df=1
# parameter F test:         F=0.8239  , p=0.3666  , df_denom=86, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4184  , p=0.6595  , df_denom=83, df_num=2
# ssr based chi2 test:   chi2=0.8872  , p=0.6417  , df=2
# likelihood ratio test: chi2=0.8828  , p=0.6431  , df=2
# parameter F test:         F=0.4184  , p=0.6595  , df_denom=83, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3417  , p=0.2668  , df_denom=80, df_num=3
# ssr based chi2 test:   chi2=4.3772  , p=0.2235  , df=3
# likelihood ratio test: chi2=4.2707  , p=0.2337  , df=3
# parameter F test:         F=1.3417  , p=0.2668  , df_denom=80, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8181  , p=0.5175  , df_denom=77, df_num=4
# ssr based chi2 test:   chi2=3.6549  , p=0.4547  , df=4
# likelihood ratio test: chi2=3.5793  , p=0.4659  , df=4
# parameter F test:         F=0.8181  , p=0.5175  , df_denom=77, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6772  , p=0.6420  , df_denom=74, df_num=5
# ssr based chi2 test:   chi2=3.8894  , p=0.5654  , df=5
# likelihood ratio test: chi2=3.8031  , p=0.5781  , df=5
# parameter F test:         F=0.6772  , p=0.6420  , df_denom=74, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5991  , p=0.7301  , df_denom=71, df_num=6
# ssr based chi2 test:   chi2=4.2526  , p=0.6425  , df=6
# likelihood ratio test: chi2=4.1484  , p=0.6566  , df=6
# parameter F test:         F=0.5991  , p=0.7301  , df_denom=71, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4471  , p=0.8688  , df_denom=68, df_num=7
# ssr based chi2 test:   chi2=3.8199  , p=0.8003  , df=7
# likelihood ratio test: chi2=3.7346  , p=0.8098  , df=7
# parameter F test:         F=0.4471  , p=0.8688  , df_denom=68, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.4905  , p=0.8587  , df_denom=65, df_num=8
# ssr based chi2 test:   chi2=4.9501  , p=0.7629  , df=8
# likelihood ratio test: chi2=4.8064  , p=0.7781  , df=8
# parameter F test:         F=0.4905  , p=0.8587  , df_denom=65, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4540  , p=0.8995  , df_denom=62, df_num=9
# ssr based chi2 test:   chi2=5.3376  , p=0.8039  , df=9
# likelihood ratio test: chi2=5.1691  , p=0.8193  , df=9
# parameter F test:         F=0.4540  , p=0.8995  , df_denom=62, df_num=9

# %%
Master_df_1

# %%
drive.mount('drive')
Master_df_1.to_csv('data_nse_covid.csv')
# !cp data_nse_covid.csv "drive/My Drive/"
